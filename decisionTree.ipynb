# %%
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split


FEATURE_NAMES = ['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width']

iris = datasets.load_iris()
X = pd.DataFrame(iris.data, columns = FEATURE_NAMES)
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(max_depth=5, criterion='gini')
model.fit(X_train,y_train)
model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 5,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
from sklearn import tree
from matplotlib import pyplot as plt

fig = plt.figure(figsize=(25, 20))

tree.plot_tree(model, class_names=["Setosa", "Versicolor", "Verginica"],feature_names=FEATURE_NAMES, filled=True, fontsize=12)
# Out:
# [Text(558.0, 996.6, 'Petal Length <= 2.6\ngini = 0.665\nsamples = 112\nvalue = [37, 34, 41]\nclass = Verginica'),
#  Text(418.5, 815.4000000000001, 'gini = 0.0\nsamples = 37\nvalue = [37, 0, 0]\nclass = Setosa'),
#  Text(697.5, 815.4000000000001, 'Petal Width <= 1.65\ngini = 0.496\nsamples = 75\nvalue = [0, 34, 41]\nclass = Verginica'),
#  Text(279.0, 634.2, 'Petal Length <= 4.95\ngini = 0.193\nsamples = 37\nvalue = [0, 33, 4]\nclass = Versicolor'),
#  Text(139.5, 453.0, 'gini = 0.0\nsamples = 32\nvalue = [0, 32, 0]\nclass = Versicolor'),
#  Text(418.5, 453.0, 'Petal Width <= 1.55\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4]\nclass = Verginica'),
#  Text(279.0, 271.79999999999995, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = Verginica'),
#  Text(558.0, 271.79999999999995, 'Petal Length <= 5.45\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = Versicolor'),
#  Text(418.5, 90.59999999999991, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Versicolor'),
#  Text(697.5, 90.59999999999991, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Verginica'),
#  Text(1116.0, 634.2, 'Petal Length <= 4.85\ngini = 0.051\nsamples = 38\nvalue = [0, 1, 37]\nclass = Verginica'),
#  Text(976.5, 453.0, 'Sepal Width <= 3.1\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]\nclass = Verginica'),
#  Text(837.0, 271.79999999999995, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = Verginica'),
#  Text(1116.0, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Versicolor'),
#  Text(1255.5, 453.0, 'gini = 0.0\nsamples = 34\nvalue = [0, 0, 34]\nclass = Verginica')]

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(X_test)
species = np.array(y_test)
predictions = np.array(y_pred)
confusion_matrix(species, predictions)
# Out:
# array([[13,  0,  0],
#        [ 0, 15,  1],
#        [ 0,  0,  9]])
